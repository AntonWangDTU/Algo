# %%
import numpy as np


P_A = 4/35
P_T = 3/35
P_G = 26/35
P_C = 2/35


S = -(1/np.log(2)) *(P_A *np.log(P_A) + P_T *np.log(P_T) +
                   P_G *np.log(P_G) + P_C *np.log(P_C))

I = 2.0 - S

I
# Out:
# 0.784040416593087

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f_E = 5/6
f_Q = 1/6


q_EM = 0.01
q_QM = 0.02


g_M = f_E * q_EM + f_Q * q_QM

alpha = 5
beta = 5

p_M =(alpha * 0 + beta * g_M)/10

#Background given
q_M = 0.02500

w_1M = 2* ( np.log(p_M/q_M)/np.log(2))


print(g_M, p_M, w_1M)
# Out:
# 0.011666666666666665 0.005833333333333333 -4.199071347101829
