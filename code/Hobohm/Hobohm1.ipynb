# %% [markdown]
# # Hobohm 1
#
# ### Fill in the blanked out part of the code (XX)

# %% [markdown]
# ## Python Imports

# %%
import numpy as np
from time import time

# %% [markdown]
# ## Data Imports

# %% [markdown]
# ## DEFINE THE PATH TO YOUR COURSE DIRECTORY

# %%
data_dir = "../../data/"

# %%
alphabet_file = data_dir + "Matrices/alphabet"
alphabet = np.loadtxt(alphabet_file, dtype=str)

alphabet

blosum_file = data_dir + "Matrices/BLOSUM50"
_blosum50 = np.loadtxt(blosum_file, dtype=int).T

blosum50 = {}

for i, letter_1 in enumerate(alphabet):
    
    blosum50[letter_1] = {}

    for j, letter_2 in enumerate(alphabet):
        
        blosum50[letter_1][letter_2] = _blosum50[i, j]

# %% [markdown]
# ### Sequences

# %%
def load_sequences():
    
    database_file = data_dir + "Hobohm/database_list.tab"
    database_list = np.loadtxt(database_file, dtype=str).reshape(-1,2)

    ids = database_list[:, 0]
    sequences = database_list[:, 1]

    return sequences, ids

# %% [markdown]
# ## Smith-Waterman O2
#
# ### This code is identical to the code you wrote the other day

# %%
def smith_waterman(query, database, scoring_scheme, gap_open, gap_extension):
    
    P_matrix, Q_matrix, D_matrix, E_matrix, i_max, j_max, max_score = smith_waterman_alignment(query, database, scoring_scheme, gap_open, gap_extension)
    
    aligned_query, aligned_database, matches = smith_waterman_traceback(E_matrix, D_matrix, i_max, j_max, query, database, gap_open, gap_extension)
    
    return aligned_query, aligned_database, matches


def smith_waterman_alignment(query, database, scoring_scheme, gap_open, gap_extension):

    # Matrix imensions
    M = len(query)
    N = len(database)
    
    # D matrix change to float
    D_matrix = np.zeros((M+1, N+1), dtype = int)

    # P matrix
    P_matrix = np.zeros((M+1, N+1), dtype = int)
    
    # Q matrix
    Q_matrix = np.zeros((M+1, N+1), dtype = int)

    # E matrix
    E_matrix = np.zeros((M+1, N+1), dtype=object)

    # Main loop
    D_matrix_max_score, D_matrix_i_max, D_matrix_i_max = -9, -9, -9
    for i in range(M-1, -1, -1):
        for j in range(N-1, -1, -1):
            
            # Q_matrix[i,j] entry
            gap_open_database = D_matrix[i+1,j] + gap_open
            gap_extension_database = Q_matrix[i+1,j] + gap_extension
            max_gap_database = max(gap_open_database, gap_extension_database)
            
            Q_matrix[i,j] = max_gap_database
                
            # P_matrix[i,j] entry
            gap_open_query = D_matrix[i,j+1] + gap_open
            gap_extension_query = P_matrix[i,j+1] + gap_extension
            max_gap_query = max(gap_open_query, gap_extension_query)
            
            P_matrix[i,j] = max_gap_query
            
            # D_matrix[i,j] entry
            diagonal_score = D_matrix[i+1,j+1] + scoring_scheme[query[i]][database[j]]    
            
            # E_matrix[i,j] entry
            candidates = [(1, diagonal_score),
                          (2, gap_open_database),
                          (4, gap_open_query),
                          (3, gap_extension_database),
                          (5, gap_extension_query)]
            
            direction, max_score = max(candidates, key=lambda x: x[1])
            
            
            # check entry sign
            if max_score > 0:
                E_matrix[i,j] = direction
            else:
                E_matrix[i,j] = 0
            
            # check max score sign
            if max_score > 0:
                D_matrix[i, j] = max_score
            else:
                D_matrix[i, j] = 0

            # fetch global max score
            if max_score > D_matrix_max_score:
                D_matrix_max_score = max_score
                D_matrix_i_max = i
                D_matrix_j_max = j
            
    return P_matrix, Q_matrix, D_matrix, E_matrix, D_matrix_i_max, D_matrix_j_max, D_matrix_max_score


def smith_waterman_traceback(E_matrix, D_matrix, i_max, j_max, query, database, gap_open, gap_extension):
    
    # Matrix imensions
    M = len(query)
    N = len(database)
    
    # aligned query string
    aligned_query = []
    
    # aligned database string
    aligned_database = []
    
    # total identical matches
    matches = 0

        
    # start from max_i, max_j
    i, j = i_max, j_max
    while i < M and j < N:

        # E[i,j] = 0, stop back tracking
        if E_matrix[i, j] == 0:
            break
        
        # E[i,j] = 1, match
        if E_matrix[i, j] == 1:
            aligned_query.append(query[i])
            aligned_database.append(database[j])
            if ( query[i] == database[j]):
                matches += 1
            i += 1
            j += 1
        
        
        # E[i,j] = 2, gap opening in database
        if E_matrix[i, j] == 2:
            aligned_database.append("-")
            aligned_query.append(query[i])
            i += 1

            
        # E[i,j] = 3, gap extension in database
        if E_matrix[i, j] == 3:
                   
            count = i + 2
            score = D_matrix[count, j] + gap_open + gap_extension
            
            # Find length of gap
            while((score - D_matrix[i, j])*(score - D_matrix[i, j]) >= 0.00001):   
                count += 1
                score = D_matrix[count, j] + gap_open + (count-i-1)*gap_extension

            for k in range(i, count):
                aligned_database.append("-")
                aligned_query.append(query[i])
                i += 1
            
            
        # E[i,j] = 4, gap opening in query
        if E_matrix[i, j] == 4:
            aligned_query.append("-")
            aligned_database.append(database[j])
            j += 1
        
        
        # E[i,j] = 5, gap extension in query
        if E_matrix[i, j] == 5:
             
            count = j + 2
            score = D_matrix[i, count] + gap_open + gap_extension
            
            # Find length of gap
            while((score - D_matrix[i, j])*(score - D_matrix[i, j]) >= 0.0001): 
                count += 1
                score = D_matrix[i, count] + gap_open + (count-j-1)*gap_extension

            for k in range(j, count):
                aligned_query.append("-")
                aligned_database.append(database[j])
                j += 1

                
    return aligned_query, aligned_database, matches

# %% [markdown]
# ## Hobohm 1

# %% [markdown]
# ### Similarity Function
#
# ### This code defines the threshold for similarity

# %%
def homology_function(alignment_length, matches):

    homology_score = 2.9 * np.sqrt(alignment_length)
    
    if matches < homology_score: ## Add the inequally sign
        return "discard", homology_score
    else:
        return "keep", homology_score

# %% [markdown]
# ### Main Loop

# %%
# load list
candidate_sequences, candidate_ids = load_sequences()
print ("# Number of elements:", len(candidate_sequences))

accepted_sequences, accepted_ids = [], []

accepted_sequences.append(candidate_sequences[0])
accepted_ids.append(candidate_ids[0])

print ("# Unique.", 0, len(accepted_sequences)-1, accepted_ids[0])

# parameters
scoring_scheme = blosum50
gap_open = -11
gap_extension = -1

t0 = time()

for i in range(1, len(candidate_sequences)):
             
    for j in range(0, len(accepted_sequences)):
        
        query = candidate_sequences[i]
        database = accepted_sequences[j]
        
        aligned_query, aligned_database, matches = smith_waterman(query, database, scoring_scheme, gap_open, gap_extension)
        
        alignment_length = len(aligned_query)
        
        homology_outcome, homology_score = homology_function(alignment_length, matches)
     
        # query is not unique
        if homology_outcome == "discard":

            print ("# Not unique.", i, candidate_ids[i], "is homolog to", accepted_ids[j], homology_score)
            
            break
            
            
    # query is unique
    if homology_outcome == "keep":
        accepted_sequences.append(query)
        accepted_ids.append(i)

        print ("# Unique.", i, len(accepted_sequences)-1, candidate_ids[i], homology_score)

t1 = time()

print ("Elapsed time (m):", (t1-t0)/60)

print ("Accepted sequences:", len(accepted_ids))
for i in range(len(accepted_ids)):
    print (accepted_ids[i])
# Out:
# # Number of elements: 1052
# # Unique. 0 0 1US0.A
# # Unique. 1 1 2EAB.A 50.89479344687431
# # Unique. 2 2 1QWN.A 71.09437389836133
# # Unique. 3 3 1HLR.A 75.67833243405936
# # Unique. 4 4 1MXT.A 63.86587508208119
# # Not unique. 5 1MUW.A is homolog to 1US0.A 39.97374138106164
# # Unique. 6 5 1SU8.A 59.99566651017388
# # Unique. 7 6 1WUI.L 58.50529890531284
# # Not unique. 8 2BHU.A is homolog to 1US0.A 38.79935566475299
# # Unique. 9 7 2E7Z.A 65.29831544534667
# # Unique. 10 8 1JZ7.A 84.8466852623012
# # Not unique. 11 1GCI._ is homolog to 7 43.306235116897426
# # Unique. 12 9 1PJX.A 56.23308634602942
# # Not unique. 13 1LQT.A is homolog to 1US0.A 23.559711373444287
# # Not unique. 14 1KWF.A is homolog to 12 35.28002267572967
# # Unique. 15 10 1MRO.A 41.62283027378123
# # Not unique. 16 1D5T.A is homolog to 1US0.A 37.36388630750287
# # Not unique. 17 1JFB.A is homolog to 7 33.44443152454531
# # Unique. 18 11 1M1N.B 70.26144034959717
# # Not unique. 19 1I1W.A is homolog to 2 46.12732378970191
# # Not unique. 20 1T3T.A is homolog to 1US0.A 41.318639861447515
# # Unique. 21 12 1EPW.A 68.68777183749665
# # Not unique. 22 1KJQ.A is homolog to 1US0.A 30.415456596934394
# # Unique. 23 13 2HEU.A 59.2196757843202
# # Unique. 24 14 1E4M.M 55.782613778846894
# # Not unique. 25 3SIL._ is homolog to 1US0.A 32.293033304414124
# # Not unique. 26 1QW9.A is homolog to 12 36.33689584981084
# # Not unique. 27 2P74.A is homolog to 1US0.A 33.819520990102745
# # Unique. 28 15 1QKS.A 53.551937406596224
# # Not unique. 29 1IXH._ is homolog to 7 37.47625915162825
# # Not unique. 30 1JEU.A is homolog to 12 25.114736709748723
# # Unique. 31 16 1HBN.B 63.99742182307034
# # Not unique. 32 1MJ5.A is homolog to 1US0.A 26.57893903074387
# # Not unique. 33 1H16.A is homolog to 1US0.A 41.216744170300494
# # Unique. 34 17 2GJ4.A 61.518289963229634
# # Unique. 35 18 1N7O.A 80.00006249997558
# # Unique. 36 19 1G5A.A 74.33283258426252
# # Unique. 37 20 2FFY.A 57.34378780652705
# # Not unique. 38 1OE1.A is homolog to 35 40.28808756940443
# # Unique. 39 21 2HPO.A 53.47335785229874
# # Unique. 40 22 2JAE.A 55.25242076144718
# # Not unique. 41 1W23.A is homolog to 7 37.13812057711052
# # Not unique. 42 2OB3.A is homolog to 18 36.682420857953204
# # Unique. 43 23 1WDP.A 54.64018667610864
# # Unique. 44 24 1HDH.A 57.636360051620194
# # Unique. 45 25 1WVF.A 62.40056089491504
# # Not unique. 46 2BMO.A is homolog to 39 28.265703599945994
# # Unique. 47 26 2J6L.B 61.791099682721295
# # Not unique. 48 1N8K.A is homolog to 1US0.A 38.14354467010112
# # Unique. 49 27 2CXN.A 63.93168228664094
# # Not unique. 50 2GAG.A is homolog to 1US0.A 33.69495511200452
# # Not unique. 51 2CNU.A is homolog to 12 33.44443152454531
# # Not unique. 52 1DS1.A is homolog to 1US0.A 20.506096654409877
# # Not unique. 53 1QTW.A is homolog to 1US0.A 27.81582283521377
# # Unique. 54 28 1LLF.A 66.82596800645689
# # Not unique. 55 1GVK.B is homolog to 2 31.23395588138012
# # Not unique. 56 1I24.A is homolog to 1US0.A 43.11159936722367
# # Unique. 57 29 1C7S.A 57.5633563997097
# # Not unique. 58 1Y2M.B is homolog to 1US0.A 34.31326274197777
# # Unique. 59 30 1O98.A 63.00412684896125
# # Not unique. 60 1X8P.A is homolog to 1US0.A 31.635265132443568
# # Not unique. 61 1T2D.A is homolog to 44 32.16255586858731
# # Not unique. 62 1IX9.A is homolog to 1US0.A 11.231651704001509
# # Unique. 63 31 1JNR.A 67.32748324421462
# # Not unique. 64 1R5Y.A is homolog to 1US0.A 20.710142442774266
# # Unique. 65 32 1OFE.A 72.61590734818371
# # Unique. 66 33 1WDD.A 61.99491914665265
# # Not unique. 67 1GPI.A is homolog to 1US0.A 24.089209202462417
# # Not unique. 68 1ODM.A is homolog to 1US0.A 28.265703599945994
# # Not unique. 69 1HYO.B is homolog to 1US0.A 42.124933234368456
# # Not unique. 70 1M15.A is homolog to 31 19.881398341163028
# # Not unique. 71 2H5D.A is homolog to 1US0.A 19.23642378406132
# # Not unique. 72 1LS1.A is homolog to 1US0.A 44.739020999570386
# # Unique. 73 34 1H1N.A 42.124933234368456
# # Unique. 74 35 1FGQ.A 57.0497151614274
# # Unique. 75 36 1W9I.A 80.31481805993212
# # Not unique. 76 1WA5.C is homolog to 12 14.5
# # Not unique. 77 1G87.B is homolog to 47 36.56760861746363
# # Not unique. 78 1R9Z.A is homolog to 73 35.04083332342426
# # Not unique. 79 1UOZ.A is homolog to 1US0.A 32.16255586858731
# # Not unique. 80 1OX0.A is homolog to 37 34.678956154994054
# # Not unique. 81 1E7U.A is homolog to 73 42.81798687467686
# # Not unique. 82 2PYX.A is homolog to 1US0.A 37.58829605076559
# # Not unique. 83 2AKZ.A is homolog to 49 44.83291201784689
# # Not unique. 84 1T1U.A is homolog to 18 44.64493252318789
# # Not unique. 85 2C1V.A is homolog to 21 27.5118156434649
# # Unique. 86 37 1FWX.A 69.84124855699531
# # Not unique. 87 1Z53.A is homolog to 2 40.703439658092776
# # Not unique. 88 1MOO.A is homolog to 6 23.380547470065792
# # Not unique. 89 1ZJY.A is homolog to 2 39.33751390212655
# # Not unique. 90 1QSA.A is homolog to 12 34.920624278497655
# # Not unique. 91 2CIW.A is homolog to 12 24.777610861420836
# # Unique. 92 38 1EDQ.A 63.99742182307034
# # Not unique. 93 1UWC.A is homolog to 1US0.A 37.92242080880386
# # Unique. 94 39 1JU3.A 65.04021832681683
# # Not unique. 95 2JG2.A is homolog to 66 32.42298567374695
# # Not unique. 96 1TZB.A is homolog to 1US0.A 38.363394010436565
# # Unique. 97 40 1F0L.A 64.39044960240611
# # Not unique. 98 2A6Z.A is homolog to 2 41.42028488554853
# # Unique. 99 41 2EZ9.A 66.76301371268376
# # Not unique. 100 1JCL.A is homolog to 4 42.71966760170308
# # Unique. 101 42 2PY5.A 54.563174394457654
# # Not unique. 102 1HBZ.A is homolog to 1US0.A 39.015509736513756
# # Not unique. 103 1RDQ.E is homolog to 3 30.827422856930482
# # Unique. 104 43 2V0C.A 63.53581667059927
# # Not unique. 105 2GSO.A is homolog to 21 23.380547470065792
# # Not unique. 106 2HAI.A is homolog to 10 28.70853531617383
# # Not unique. 107 2JG0.A is homolog to 1US0.A 39.65690356041429
# # Not unique. 108 2H1V.A is homolog to 37 37.92242080880386
# # Not unique. 109 1E9G.A is homolog to 1US0.A 28.265703599945994
# # Not unique. 110 1MW9.X is homolog to 43 38.69082578596637
# # Not unique. 111 1FSG.A is homolog to 1US0.A 32.293033304414124
# # Not unique. 112 1QJ4.A is homolog to 6 30.69071520834925
# # Not unique. 113 2BLN.A is homolog to 1US0.A 15.068842025849232
# # Not unique. 114 2FAF.A is homolog to 101 36.22098839071071
# # Not unique. 115 2A3N.A is homolog to 6 35.988053573373485
# # Unique. 116 44 1OGO.X 41.824394795382275
# # Unique. 117 45 1X38.A 72.20941766833465
# # Not unique. 118 1Z2N.X is homolog to 1US0.A 39.015509736513756
# # Unique. 119 46 1NNM.A 67.8252902684537
# # Not unique. 120 2WEA._ is homolog to 1US0.A 22.834622834634253
# # Not unique. 121 1X54.A is homolog to 6 41.11459594839769
# # Not unique. 122 2Z26.A is homolog to 28 32.293033304414124
# # Not unique. 123 1LOK.A is homolog to 1US0.A 31.368296096536707
# # Unique. 124 47 2NQ5.A 73.82194795587556
# # Not unique. 125 1F9Y.A is homolog to 1US0.A 31.767908335299634
# # Not unique. 126 1IV8.A is homolog to 4 35.28002267572967
# # Not unique. 127 1Z70.X is homolog to 4 36.33689584981084
# # Not unique. 128 1LC0.A is homolog to 1US0.A 40.18357873559795
# # Not unique. 129 1F8D.A is homolog to 4 35.988053573373485
# # Not unique. 130 1QMG.A is homolog to 1US0.A 38.0331434409516
# # Not unique. 131 1M4L.A is homolog to 1US0.A 31.502063424480625
# # Not unique. 132 1QOP.B is homolog to 37 43.11159936722367
# # Not unique. 133 2DCF.A is homolog to 21 39.015509736513756
# # Not unique. 134 2UYT.A is homolog to 73 30.276888875840594
# # Not unique. 135 1F5N.A is homolog to 4 32.55241926493329
# # Not unique. 136 1ITW.A is homolog to 1US0.A 38.5819906173852
# # Unique. 137 48 1KXQ.A 38.14354467010112
# # Not unique. 138 1ZHX.A is homolog to 6 27.664236841091423
# # Not unique. 139 1X6Z.A is homolog to 1US0.A 34.06728636096511
# # Not unique. 140 1ODZ.A is homolog to 1US0.A 30.55339588327294
# # Unique. 141 49 1RLL.A 57.7820906509967
# # Not unique. 142 1I19.A is homolog to 1US0.A 41.318639861447515
# # Unique. 143 50 1Q7Z.A 69.35791230998811
# # Unique. 144 51 1QWO.A 56.82816203256972
# # Not unique. 145 1NOF.A is homolog to 1US0.A 38.363394010436565
# # Unique. 146 52 1EEX.A 50.061761854733
# # Not unique. 147 1AOP._ is homolog to 12 32.68134024179547
# # Not unique. 148 2HBW.A is homolog to 1US0.A 33.065087327875
# # Unique. 149 53 2JFG.A 58.57712864250005
# # Not unique. 150 1H2V.C is homolog to 12 39.762796682326055
# # Not unique. 151 2G50.D is homolog to 137 33.19201711255283
# # Not unique. 152 1XG0.D is homolog to 1US0.A 38.363394010436565
# # Unique. 153 54 1WPG.A 61.72301029599901
# # Not unique. 154 1RQW.A is homolog to 1US0.A 40.6
# # Unique. 155 55 1N0U.A 84.14998514557206
# # Not unique. 156 2CZQ.A is homolog to 9 39.33751390212655
# # Not unique. 157 1NWZ.A is homolog to 1US0.A 23.2
# # Not unique. 158 2A65.A is homolog to 1US0.A 18.56906028855526
# # Not unique. 159 2AEB.A is homolog to 1US0.A 39.23047284955918
# # Not unique. 160 1UVJ.A is homolog to 1US0.A 38.0331434409516
# # Not unique. 161 1MRO.C is homolog to 1US0.A 36.56760861746363
# # Not unique. 162 1R1H.A is homolog to 12 31.9
# # Not unique. 163 1X6V.A is homolog to 31 27.204411406975893
# # Not unique. 164 2G8C.O is homolog to 6 30.415456596934394
# # Unique. 165 56 1O94.A 67.0771943360782
# # Unique. 166 57 1MV8.A 59.64419502348908
# # Not unique. 167 1GPE.A is homolog to 1US0.A 45.57707757195496
# # Not unique. 168 1WB9.A is homolog to 12 32.42298567374695
# # Unique. 169 58 1XJJ.A 54.176470907581276
# # Not unique. 170 2HR0.B is homolog to 59 44.36146976825723
# # Not unique. 171 2J7N.A is homolog to 12 45.29944812025859
# # Unique. 172 59 1HP1.A 68.13457272193023
# # Not unique. 173 2C5A.A is homolog to 1 28.854635676091977
# # Not unique. 174 2BWR.A is homolog to 1US0.A 43.306235116897426
# # Not unique. 175 1EB6.A is homolog to 1US0.A 24.946743274423618
# # Not unique. 176 2C71.A is homolog to 1 31.23395588138012
# # Not unique. 177 1XDN.A is homolog to 1US0.A 32.809754647055804
# # Not unique. 178 2B6D.A is homolog to 18 35.63579660958907
# # Not unique. 179 2O7A.A is homolog to 1US0.A 15.345357604174625
# # Not unique. 180 1W66.A is homolog to 7 27.664236841091423
# # Not unique. 181 1P5D.X is homolog to 66 31.368296096536707
# # Not unique. 182 1EJD.A is homolog to 12 29.716157221282835
# # Not unique. 183 1QHA.B is homolog to 37 25.281613872535907
# # Not unique. 184 2CFM.A is homolog to 24 33.44443152454531
# # Not unique. 185 2DSN.A is homolog to 12 38.47284756812264
# # Not unique. 186 1NEY.A is homolog to 1US0.A 37.811373950175366
# # Not unique. 187 1SI0.A is homolog to 2 36.33689584981084
# # Not unique. 188 1H4G.B is homolog to 2 31.767908335299634
# # Not unique. 189 2HC1.A is homolog to 1US0.A 43.59655949728143
# # Not unique. 190 2H6F.B is homolog to 1US0.A 39.12313893337292
# # Not unique. 191 2H4A.A is homolog to 1US0.A 38.253627278991466
# # Not unique. 192 2DVM.A is homolog to 166 38.90758280849634
# # Not unique. 193 2CFU.A is homolog to 1US0.A 43.5
# # Not unique. 194 1Y79.1 is homolog to 12 29.431785538767436
# # Not unique. 195 1CSH._ is homolog to 12 43.306235116897426
# # Not unique. 196 1LJ8.A is homolog to 73 46.03607281252388
# # Not unique. 197 1UUQ.A is homolog to 1US0.A 30.415456596934394
# # Not unique. 198 1YIZ.A is homolog to 15 37.811373950175366
# # Not unique. 199 1MC2.A is homolog to 1US0.A 31.368296096536707
# # Not unique. 200 1KMV.A is homolog to 1US0.A 32.16255586858731
# # Not unique. 201 1O7Q.A is homolog to 1US0.A 42.91608090215135
# # Not unique. 202 1GVE.B is homolog to 12 26.57893903074387
# # Unique. 203 60 1E43.A 62.93734980121105
# # Not unique. 204 2P1M.B is homolog to 7 43.692905602626155
# # Unique. 205 61 1IVU.A 68.99318806954784
# # Not unique. 206 1YMT.A is homolog to 3 25.775763810215206
# # Not unique. 207 1UCS.A is homolog to 1US0.A 14.787156589419075
# # Unique. 208 62 1OFL.A 65.10483852986658
# # Not unique. 209 2CE2.X is homolog to 1US0.A 22.649724060129294
# # Not unique. 210 1W5Q.A is homolog to 7 40.18357873559795
# # Not unique. 211 2D5M.A is homolog to 1US0.A 34.31326274197777
# ----------------------------------------------------------------
# KeyboardInterrupt              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2964\1650369951.py in <module>
#      24         database = accepted_sequences[j]
#      25
# ---> 26         aligned_query, aligned_database, matches = smith_waterman(query, database, scoring_scheme, gap_open, gap_extension)
#      27
#      28         alignment_length = len(aligned_query)
#
# ~\AppData\Local\Temp\ipykernel_2964\3692749336.py in smith_waterman(query, database, scoring_scheme, gap_open, gap_extension)
#       1 def smith_waterman(query, database, scoring_scheme, gap_open, gap_extension):
#       2
# ----> 3     P_matrix, Q_matrix, D_matrix, E_matrix, i_max, j_max, max_score = smith_waterman_alignment(query, database, scoring_scheme, gap_open, gap_extension)
#       4
#       5     aligned_query, aligned_database, matches = smith_waterman_traceback(E_matrix, D_matrix, i_max, j_max, query, database, gap_open, gap_extension)
#
# ~\AppData\Local\Temp\ipykernel_2964\3692749336.py in smith_waterman_alignment(query, database, scoring_scheme, gap_open, gap_extension)
#      34             gap_open_database = D_matrix[i+1,j] + gap_open
#      35             gap_extension_database = Q_matrix[i+1,j] + gap_extension
# ---> 36             max_gap_database = max(gap_open_database, gap_extension_database)
#      37
#      38             Q_matrix[i,j] = max_gap_database
#
# KeyboardInterrupt:
